# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('all_season_details.csv')
# Out:
# /home/sujan/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (25) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#         comment_id  season  match_id match_name home_team away_team  \
# 0              110    2020   1216492   MI v CSK        MI       CSK
# 1              120    2020   1216492   MI v CSK        MI       CSK
# 2              130    2020   1216492   MI v CSK        MI       CSK
# 3              140    2020   1216492   MI v CSK        MI       CSK
# 4              150    2020   1216492   MI v CSK        MI       CSK
# ...            ...     ...       ...        ...       ...       ...
# 192815      219020    2008    336040   CSK v RR       CSK        RR
# 192816      219030    2008    336040   CSK v RR       CSK        RR
# 192817      219050    2008    336040   CSK v RR       CSK        RR
# 192818      219040    2008    336040   CSK v RR       CSK        RR
# 192819      219060    2008    336040   CSK v RR       CSK        RR
#
#        current_innings  innings_id  over  ball  ...  wicket_id  \
# 0                   MI           1     1     1  ...        NaN
# ...

# %%
df.season.unique()
# Out:
# array([2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010,
#        2009, 2008])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192820 entries, 0 to 192819
# Data columns (total 45 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   comment_id         192820 non-null  int64
#  1   season             192820 non-null  int64
#  2   match_id           192820 non-null  int64
#  3   match_name         192820 non-null  object
#  4   home_team          192820 non-null  object
#  5   away_team          192820 non-null  object
#  6   current_innings    192820 non-null  object
#  7   innings_id         192820 non-null  int64
#  8   over               192820 non-null  int64
#  9   ball               192820 non-null  int64
#  10  runs               192820 non-null  int64
#  11  shortText          192820 non-null  object
#  12  isBoundary         192820 non-null  bool
#  13  isWide             192820 non-null  bool
#  14  isNoball           192820 non-null  bool
# ...
